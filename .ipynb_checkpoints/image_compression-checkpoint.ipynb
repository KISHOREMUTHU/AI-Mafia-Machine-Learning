# %%
from PIL import Image
import PIL
import os
import glob

# %%
im = Image.open("C:/Users/dell/Downloads/compressed/Compressed_and_resized_login.jpg")

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=999x1080 at 0x24AD11E97F0>

# %%
file_name ="login.jpg"
im.save("compressed_"+file_name,optimize=True,quality=10)

# %%
os.chdir('C:/Users/dell/Downloads/folder/')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\dell\\Downloads\\folder'

# %%
os.listdir()
# Out:
# ['amazon_music.png',
#  'apple_music.png',
#  'deezer.png',
#  'gaana.png',
#  'hungama.jpg',
#  'iheartradio.png',
#  'jiosaavn.png',
#  'resso.webp',
#  'soundcloud.png',
#  'spotify.png',
#  'tidal.png',
#  'tinkoff.gif',
#  'tjournal.png',
#  'toggi.png',
#  'torguard.png',
#  'tothemoon.png',
#  'trainingpeaks.jpg',
#  'trakt.png',
#  'treehouse.png',
#  'trello.jpg',
#  'tripit.png',
#  'tunein.png',
#  'tunnelbear.png',
#  'tvforecast.jpg',
#  'tweetbot.jpg',
#  'twitch.png',
#  'ui.jpg',
#  'uniplater.jpg',
#  'universalman.jpg',
#  'vas3k.jpg',
#  'vcplus.png',
#  'verizon.png',
#  'wynk.png',
#  'youtube_music.png']

# %%
images =[] 
for file in os.listdir():
    if file.endswith(('jpg', 'png','jpeg','webp','gif' )):
        images.append(file)

# %%
images
# Out:
# ['amazon_music.png',
#  'apple_music.png',
#  'deezer.png',
#  'gaana.png',
#  'hungama.jpg',
#  'iheartradio.png',
#  'jiosaavn.png',
#  'resso.webp',
#  'soundcloud.png',
#  'spotify.png',
#  'tidal.png',
#  'tinkoff.gif',
#  'tjournal.png',
#  'toggi.png',
#  'torguard.png',
#  'tothemoon.png',
#  'trainingpeaks.jpg',
#  'trakt.png',
#  'treehouse.png',
#  'trello.jpg',
#  'tripit.png',
#  'tunein.png',
#  'tunnelbear.png',
#  'tvforecast.jpg',
#  'tweetbot.jpg',
#  'twitch.png',
#  'ui.jpg',
#  'uniplater.jpg',
#  'universalman.jpg',
#  'vas3k.jpg',
#  'vcplus.png',
#  'verizon.png',
#  'wynk.png',
#  'youtube_music.png']

# %%
os.chdir('C:/Users/dell/Downloads/folder/')
for image in images:
    # 1. Open the image
    img = Image.open(image)
    # 2. Compressing the image
    img.save(image,
             optimize=True,
             quality=10)
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\PIL\Image.py:2942: UserWarning: image file could not be identified because WEBP support not installed
#   warnings.warn(message)
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-10-f6c677a5f33d> in <module>
#       2 for image in images:
#       3     # 1. Open the image
# ----> 4     img = Image.open(image)
#       5     # 2. Compressing the image
#       6     img.save(image,
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2941     for message in accept_warnings:
#    2942         warnings.warn(message)
# -> 2943     raise UnidentifiedImageError(
#    2944         "cannot identify image file %r" % (filename if filename else fp)
#    2945     )
#
# UnidentifiedImageError: cannot identify image file 'resso.webp'
