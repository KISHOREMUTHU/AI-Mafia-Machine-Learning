# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('C:/Users/dell/Downloads/forest3.jpg')
plt.imshow(img)
original_img =img
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.show()

# %%
print(img)
print(img.shape)
# Out:
# [[[ 72  73  91]
#   [ 72  73  91]
#   [ 71  74  89]
#   ...
#   [ 48  68  69]
#   [ 48  68  69]
#   [ 48  68  69]]
#
#  [[ 79  81  96]
#   [ 77  80  95]
#   [ 76  80  92]
#   ...
#   [ 52  72  73]
#   [ 52  72  73]
#   [ 52  72  73]]
#
#  [[ 82  86  97]
#   [ 81  85  96]
#   [ 78  82  91]
#   ...
#   [ 57  77  76]
#   [ 57  77  76]
#   [ 57  77  76]]
#
#  ...
#
#  [[112 126  91]
#   [ 86 100  67]
#   [ 51  64  36]
#   ...
#   [ 57  79  67]
#   [ 57  79  67]
#   [ 57  79  67]]
#
#  [[ 75  89  54]
#   [ 61  75  42]
#   [ 45  58  30]
#   ...
#   [ 57  79  67]
#   [ 57  79  67]
#   [ 57  79  67]]
#
#  [[ 72  86  51]
#   [ 58  72  39]
#   [ 42  55  27]
#   ...
#   [ 57  79  67]
#   [ 57  79  67]
#   [ 57  79  67]]]
# (330, 500, 3)

# %%
# Flatten each channel of the image in a linear array
all_pixels = img.reshape((330*500,3))
print(all_pixels.shape)
# Out:
# (165000, 3)

# %%
from sklearn.cluster import KMeans

# %%
dominant_colors = 4
km = KMeans(n_clusters = dominant_colors)
km.fit(all_pixels)
# Out:
# KMeans(n_clusters=4)

# %%
centers = km.cluster_centers_
centers =np.array(centers,dtype ='uint8')
print(centers)
# Out:
# [[ 28  44  35]
#  [ 98 106  81]
#  [ 53  68  55]
#  [173 172 112]]

# %%
# Plot what all colors are these values ? 
i=1
colors =[]
for each_color in centers:
    plt.subplot(1,4,i)
    plt.axis('off')
    i+=1
    colors.append(each_color)
    # color swatch
    a = np.zeros((100,100,3), dtype ='uint8')
    a[:,:,:] = each_color
    plt.imshow(a)
plt.show()

# %% [markdown]
# # Segmenting Original Image

# %%
new_img = np.zeros((330*500,3),dtype ='uint8')
print(new_img.shape)
# Out:
# (165000, 3)

# %%
a = km.labels_
print(len(a))
colors
# Out:
# 165000
# [array([28, 44, 35], dtype=uint8),
#  array([ 98, 106,  81], dtype=uint8),
#  array([53, 68, 55], dtype=uint8),
#  array([173, 172, 112], dtype=uint8)]

# %%
for each_pixel in range(new_img.shape[0]):
    new_img[each_pixel] = colors[km.labels_[each_pixel]]

# %%
print(new_img)
# Out:
# [[53 68 55]
#  [53 68 55]
#  [53 68 55]
#  ...
#  [53 68 55]
#  [53 68 55]
#  [53 68 55]]

# %%
print(new_img.shape)
# Out:
# (165000, 3)

# %%
new_img = new_img.reshape((original_img.shape))
plt.imshow(original_img)
plt.show()

# %%
plt.imshow(new_img)
